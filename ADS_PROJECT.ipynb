# %%
import pandas as pd

# Load dataset
df = pd.read_csv(r"c:\Users\admin\Documents\Downloads\archive\traffic.csv")

# View first rows
print(df.head())

# Check info
print(df.info())

# %%
df = pd.read_csv(r"c:\Users\admin\Documents\Downloads\archive\traffic.csv", nrows=5000)
